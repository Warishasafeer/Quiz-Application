# %%
answer1 = input("what is the name of Pakistani currency? \na. Rupee \nb. Dollar \nc. Euro \nd. Dirham \n answer: ")
if answer1 == "a" or answer1 == "Rupee":
    correct =+ 1
    print ("correct!")
    print ("correct: ", correct)
    print("\n")
else:
    print("incorrect!")
    print ( "correct: ", correct)
    print("\n")

answer2 = input("which is the most populated country in the world? \na. Pakistan \nb. China \nc. India \nd. USA \n answer: ")
if answer2 == "b" or answer2 == "China":
    correct+= 1
    print ("correct!")
    print ( "correct: ", correct),
    print("\n")
else:
    print("incorrect!")
    print( "correct: ", correct)
    print("\n")
    
answer3 = input("which is the most popular sofware in the world? \na. Python \nb. Java \nc. C# \nd. C++ \n answer: ")
if answer3 == "a" or answer3 == "Python":
    correct+= 1
    print ("correct!")
    print ( "correct: ", correct)
    print("\n")
else:
    print("incorrect!")
    print( "correct: ", correct)
    print("\n")
    
answer4 = input("What is the capital of Pakistan? \na. Karachi \nb. Islamabad \nc. Quetta \nd. Lahore \n answer: ")
if answer4 == "b" or answer4 == "Islamabad":
    correct+= 1
    print ("correct!")
    print ( "correct: ", correct)
    print("\n")
else:
    print("incorrect!")
    print( "correct: ", correct)
    print("\n")
    
answer5 = input("Karachi loves? \na. Biryani \nb. Wall art \nc. Seaside \nd. Parks \n answer: ")
if answer5 == "a" or answer5 == "Biryani":
    correct+= 1
    print ("correct!")
    print ( "correct: ", correct)
    print("\n")
else:
    print("incorrect!")
    print("correct: ", correct)
    print("\n")

print ("that is a score of", (correct*100)/5*1.0, "percent")
# Out:
# what is the name of Pakistani currency?
# a. Rupee
# b. Dollar
# c. Euro
# d. Dirham
#  answer: Rupee
# correct!
# correct:  1
#
#
# which is the most populated country in the world?
# a. Pakistan
# b. China
# c. India
# d. USA
#  answer: China
# correct!
# correct:  2
#
#
# which is the most popular sofware in the world?
# a. Python
# b. Java
# c. C#
# d. C++
#  answer: Python
# correct!
# correct:  3
#
#
# What is the capital of Pakistan?
# a. Karachi
# b. Islamabad
# c. Quetta
# d. Lahore
#  answer: Islamabad
# correct!
# correct:  4
#
#
# Karachi loves?
# a. Biryani
# b. Wall art
# c. Seaside
# d. Parks
#  answer: Biryani
# correct!
# correct:  5
#
#
# that is a score of 100.0 percent
